# %%
isochrone_file = './geneva_isochrones.dat'
from astropy.table import Table
import crds
geneva_av0 = Table.read(isochrone_file, format='ascii', data_start=2)
print(geneva_av0)
# Out:
#  M_ini  Z_ini  OmOc_ini    M    ...    O18       Ne20      Ne22      Al26
# ------- ------ -------- ------- ... --------- --------- --------- ---------
#     1.7 0.0004      0.0     1.7 ... 3.686e-07 5.363e-05 4.337e-06       0.0
#   1.851 0.0004      0.0   1.851 ... 3.686e-07 5.363e-05 4.337e-06       0.0
#   2.016 0.0004      0.0   2.016 ... 3.686e-07 5.363e-05 4.337e-06       0.0
#   2.195 0.0004      0.0   2.195 ... 3.686e-07 5.363e-05 4.337e-06       0.0
#    2.39 0.0004      0.0    2.39 ... 3.686e-07 5.363e-05 4.337e-06       0.0
#   2.602 0.0004      0.0   2.602 ... 3.686e-07 5.363e-05 4.337e-06       0.0
#   2.833 0.0004      0.0   2.833 ... 3.686e-07 5.363e-05 4.337e-06       0.0
#   3.085 0.0004      0.0   3.085 ... 3.686e-07 5.363e-05 4.337e-06       0.0
#   3.359 0.0004      0.0   3.359 ... 3.686e-07 5.363e-05 4.337e-06       0.0
#   3.658 0.0004      0.0   3.658 ... 3.686e-07 5.363e-05 4.337e-06       0.0
# ...
