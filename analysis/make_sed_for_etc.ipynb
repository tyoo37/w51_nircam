# %%
import numpy as np

freq = np.genfromtxt('/Users/dbahck37/Documents/cmfgen_ostar_freq.csv')
intensity = np.genfromtxt('/Users/dbahck37/Documents/cmfgen_ostar_intensity.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 intensity = np.genfromtxt('/Users/dbahck37/Documents/cmfgen_ostar_intensity.csv')
#       4 freq = np.genfromtxt('/Users/dbahck37/Documents/cmfgen_ostar_freq.csv')
#       6 print(freq)
#
# File ~/anaconda3/envs/py311/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:2007, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    2005     fname = os.fspath(fname)
#    2006 if isinstance(fname, str):
# -> 2007     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    2008     fid_ctx = contextlib.closing(fid)
#    2009 else:
#
# ...
