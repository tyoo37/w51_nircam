# %%
from protopop.cluster import Cluster
from astropy import units as u
import numpy as np
cl_ca = Cluster(distance=5.4 * u.kpc, timescale=1 * u.Myr, mass=1e4*u.Msun, history='ca', efficiency=1.0 )

cl_tc = Cluster(distance=5.4 * u.kpc, timescale=1 * u.Myr, mass=1e4*u.Msun, history='tc', efficiency=1.0 )
# Out:
# Setting up...
# Calculating initial conditions...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 4
#       2 from astropy import units as u
#       3 import numpy as np
# ----> 4 cl_ca = Cluster(distance=5.4 * u.kpc, timescale=1 * u.Myr, mass=1e4*u.Msun, history='ca', efficiency=1.0 )
#       6 cl_tc = Cluster(distance=5.4 * u.kpc, timescale=1 * u.Myr, mass=1e4*u.Msun, history='tc', efficiency=1.0 )
#
# File /blue/adamginsburg/t.yoo/from_red/miniconda3/envs/py311/lib/python3.11/site-packages/protopop/cluster.py:116, in Cluster.__init__(self, mass, imf, sampling, stop_criterion, history, sfh, timescale, efficiency, distance, T_res, R_res, mu, read_only)
#     113 unit_check(mu, 'mass')
#     114 self._res_props = [T_res, R_res, mu]
# --> 116 self._construct()
#
# ...

# %%
from protopop.util import util
import glob
print("datapath:", util.datapath)
print("protostar files:", glob.glob(f"{util.datapath}/track_data/protostar_tracks/tc/*.txt"))
print("flux files:", glob.glob(f"{util.datapath}/track_data/flux_tracks/tc/*"))
# Out:
# datapath: /blue/adamginsburg/t.yoo/from_red/miniconda3/envs/py311/lib/python3.11/site-packages/protopop/util/..
# protostar files: []
# flux files: []
