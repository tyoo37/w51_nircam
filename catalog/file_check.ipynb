# %%
import glob
filters = ['F140M', 'F162M', 'F182M', 'F187N', 'F210M', 'F335M', 'F360M', 'F405N', 'F410M', 'F480M']

for filter in filters:
    path = f'/orange/adamginsburg/jwst/w51/{filter}/pipeline/*crf.fits'
    print(filter, len(glob.glob(path)), glob.glob(path))
    path = f'/orange/adamginsburg/jwst/w51/{filter}/pipeline/*destreak*crf.fits'
    print(filter, len(glob.glob(path)), glob.glob(path))
    path = f'/orange/adamginsburg/jwst/w51/{filter}/pipeline/*satstar_catalog.fits'
    print(filter, len(glob.glob(path)), glob.glob(path))
    path = f'/orange/adamginsburg/jwst/w51/{filter}/pipeline/*recenter*'
    print(filter, len(glob.glob(path)), glob.glob(path))
# Out:
# F140M 128 ['/orange/adamginsburg/jwst/w51/F140M/pipeline/jw06151001001_03109_00006_nrcb4_align_o001_crf.fits', '/orange/adamginsburg/jwst/w51/F140M/pipeline/jw06151001001_03109_00005_nrcb3_destreak_o001_crf.fits', '/orange/adamginsburg/jwst/w51/F140M/pipeline/jw06151001001_03109_00007_nrca3_align_o001_crf.fits', '/orange/adamginsburg/jwst/w51/F140M/pipeline/jw06151001001_03109_00003_nrca1_align_o001_crf.fits', '/orange/adamginsburg/jwst/w51/F140M/pipeline/jw06151001001_03109_00002_nrcb1_destreak_o001_crf.fits', '/orange/adamginsburg/jwst/w51/F140M/pipeline/jw06151001001_03109_00001_nrca1_align_o001_crf.fits', '/orange/adamginsburg/jwst/w51/F140M/pipeline/jw06151001001_03109_00003_nrca2_align_o001_crf.fits', '/orange/adamginsburg/jwst/w51/F140M/pipeline/jw06151001001_03109_00006_nrca2_destreak_o001_crf.fits', '/orange/adamginsburg/jwst/w51/F140M/pipeline/jw06151001001_03109_00004_nrca3_destreak_o001_crf.fits', '/orange/adamginsburg/jwst/w51/F140M/pipeline/jw06151001001_03109_00007_nrc
# ...
